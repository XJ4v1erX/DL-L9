# %% [markdown]
# # Lab-9-DL
# Javier Ramírez 21600

# %%
# !pip -q install transformers einops accelerate

# %%
from transformers import AutoTokenizer
import transformers

# %% [markdown]
# # TinyLlama

# %%
model = "TinyLlama/TinyLlama_v1.1"
tokenizer = AutoTokenizer.from_pretrained(model)

pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer
)
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
prompt = "Explain to me the difference between nuclear fission and fusion."
response = pipeline(
    prompt,
    max_length=500,
    truncation = True,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)
print(response[0]['generated_text'])
# Out:
# Explain to me the difference between nuclear fission and fusion.
# "The most exciting and most interesting scientific developments of the past half century were not achieved by physicists or engineers but by chemists," writes Robert Laughlin, professor of condensed matter physics, in a recent article for the Harvard Gazette. "They were made by chemists who studied molecules and then applied their findings to other fields."
# Laughlin's research focuses on quantum coherence and topological phases of matter. The latter, a term he coined in 1981, refers to a variety of unusual states of matter that exist when certain quantum-mechanical properties are preserved, like the existence of a magnetic monopole.
# In 2018, the Nobel committee recognized Laughlin's work, which helped lay the foundation for topological phases of matter, as one of three winners of its 2018 physics prize. The other two were physicists Andrei Kitaev of MIT and R. Albert Ho of UC Berkeley.
# Topological phases of matter are a type of quantum superfluid, a phenomenon first predicted by Laughlin's mentor, Nobel laureate Robert B. Laughlin, in the late 1970s.
# "Laughlin's work was very groundbreaking because it was the first time that anyone had shown that a physical system can exhibit topological properties without any symmetry," said Laughlin, whose work on superlattices and topological superconductivity has also earned him the distinction of being the 2017 American Physical Society's John von Neumann Lecturer.
# "It also led to the development of topological insulators, which are superinsulators that can be superconductors at the same time."
# Topological phases of matter have applications in superconductivity and in information technology, such as the development of 2D materials.
# "The development of topological insulation has made possible a new class of superconducting devices," Laughlin explained in the Harvard Gazette article. "They have the same superconducting properties as conventional devices, but they are insulated from the magnetic fields and electromagnetic radiation that can damage conventional superconductors."
# Topological superconductors can also be used to

# %% [markdown]
# # Doctor-Shotgun/TinyLlama-1.1B-32k-Instruct

# %%
model = "Doctor-Shotgun/TinyLlama-1.1B-32k-Instruct"
tokenizer = AutoTokenizer.from_pretrained(model)

pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer
)
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.70k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/551 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/695 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.20G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/129 [00:00<?, ?B/s]
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
prompt = "Explain to me the difference between nuclear fission and fusion."
response = pipeline(
    prompt,
    max_length=500,
    truncation = True,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)
print(response[0]['generated_text'])
# Out:
# Explain to me the difference between nuclear fission and fusion. Which one is the most prevalent type of energy used for power generation?
# What is the energy used in nuclear fission used for?
# What are the major components of a nuclear fuel cycle?
# What are two differences between nuclear fission and fission?
# What is the difference between nuclear fission and fusion in nuclear fission?
# How can nuclear energy be produced without the use of fusion reactions?
# Nuclear fission: The separation of an atom into smaller particles is called fission. In nuclear fission, a large mass of uranium-235 is split apart through the release of energy, forming a small amount of energy-releasing isotope like plutonium 239. Nuclear fusion occurs when two helium-4 atoms are combined.
# Nuclear fusion: The fusion reaction occurs inside the core, converting one proton and one neutron into a single neutron and two protons. The energy produced in the process of nuclear fusion is used to generate electrical power.
# Nuclear power can be used for electricity or to generate hydrogen fuel for fuel cells. The process involves using neutrons, a type of particle, to split atomic nuclei. The resulting particles, called neutrons, are used to generate electricity in nuclear power plants.
# Nuclear fusion is the most common type of energy used for power generation. It is used in reactors at nuclear power plants. The process involves a large quantity of fuel, typically uranium or plutonium-238. This fuel is placed inside the reactor and heated by neutrons, which cause the nuclei to combine. The neutrons produce energy when they collide with other neutrons, and they then release this energy in the form of heat and radiation.
# In nuclear fusion, two atoms or molecules of hydrogen are fused together into one atom or molecule of helium-4. This process releases a tremendous amount of energy, but also creates a neutron in the process. These neutrons can then be used to generate electrical power.

# %% [markdown]
# # EleutherAI/gpt-neo-1.3B

# %%
model_3 = "EleutherAI/gpt-neo-1.3B"

tokenizer = AutoTokenizer.from_pretrained(model)

pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer
)
# Out:
# Hardware accelerator e.g. GPU is available in the environment, but no `device` argument is passed to the `Pipeline` object. Model will be on CPU.

# %%
prompt = "Explain to me the difference between nuclear fission and fusion."
response = pipeline(
    prompt,
    max_length=500,
    truncation = True,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)
print(response[0]['generated_text'])
# Out:
# Explain to me the difference between nuclear fission and fusion.
# Explain the difference between nuclear fusion and nuclear fission.
# 1) Nuclear fusion is the process by which energy is converted in to matter. In fusion, two nuclei of the same atom join together to form a new nucleus. In nuclear fission, a nuclear nucleus splits apart into two fragments with each fragment being smaller than the whole nucleus.
# 2) Nuclear fusion releases the highest amount of energy, while nuclear fission produces the lowest amount of energy. This difference in energy production is the cause of nuclear weapons, nuclear power generation, and nuclear power plants. The higher energy is needed for nuclear fission to produce more energy and nuclear power plants are generally built to produce more energy than nuclear fusion.
# 3) The nuclear fusion process releases the largest amount of energy, while the nuclear fission process releases the smallest amount of energy. This difference in energy production is the main reason for the difference between nuclear fission and nuclear fusion.
# 4) Nuclear fusion occurs when an atom splits up to form two smaller atoms. Nuclear fusion produces the highest amount of energy, making it the most destructive process in nuclear weapons and nuclear power plants. Nuclear fusion in power plants produces more energy because it releases more heat, but nuclear fusion is less efficient than nuclear fission, which releases less energy.
# 5) Nuclear fusion is used in the construction of stars and in some nuclear power plants. Nuclear fission is used in nuclear weapons and nuclear power plants.
